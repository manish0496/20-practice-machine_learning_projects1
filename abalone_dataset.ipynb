# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# 3             0.1140        0.1550     10
# 4             0.0395        0.0550      7
# 5             0.0775        0.1200      8
# 6             0.1415        0.3300     20
# 7             0.1495        0.2600     16
# 8             0.1125        0.1650      9
# 9             0.1510        0.3200     19
# 10            0.1475        0.2100     14
# 11            0.0810        0.1350     10
# 12            0.0950        0.1900     11
# 13            0.1710        0.2050     10
# 14            0.0805        0.1850     10
# 15            0.1330        0.2400     12
# 16            0.0395        0.1150      7
# 17            0.0870        0.1300     10
# 18            0.0430        0.1000      7
# 19            0.0750        0.1150      9
# 20            0.0620        0.0750     11
# 21            0.0490        0.0850     10
# 22            0.2140        0.2700     12
# 23            0.2100        0.2000      9
# 24            0.3010        0.3050     10
# 25            0.1880        0.3000     11
# 26            0.2720        0.2850     11
# 27            0.2340        0.2800     12
# 28            0.2190        0.2950     15
# 29            0.2270        0.2000     11
# ...              ...           ...    ...
# 4147          0.3600        0.4450     11
# 4148          0.5260        0.3550     11
# 4149          0.0215        0.0300      6
# 4150          0.0365        0.0460      7
# 4151          0.0355        0.0410      6
# 4152          0.0545        0.0615      7
# 4153          0.0715        0.1100      8
# 4154          0.0750        0.0885      6
# 4155          0.0895        0.1150      6
# 4156          0.1070        0.1460      8
# 4157          0.1045        0.1550      8
# 4158          0.0890        0.1400      8
# 4159          0.1615        0.2590      9
# 4160          0.2170        0.3000     11
# 4161          0.2630        0.2845     11
# 4162          0.0680        0.0920      8
# 4163          0.0695        0.0790      7
# 4164          0.0635        0.0810      7
# 4165          0.0505        0.0880      7
# 4166          0.0885        0.1560     10
# 4167          0.1265        0.1535      9
# 4168          0.1230        0.1765      8
# 4169          0.1800        0.1815     10
# 4170          0.1955        0.2405     10
# 4171          0.1720        0.2290      8
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
#Lets check whether there are null values or not
df_abalone.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
#Lets check the  Datatypes of each column
df_abalone.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
#Lets correlation matrix
df_abalone.corr()
# Out:
#                   Length  Diameter    Height  Whole weight  Shucked weight  \
# Length          1.000000  0.986812  0.827554      0.925261        0.897914
# Diameter        0.986812  1.000000  0.833684      0.925452        0.893162
# Height          0.827554  0.833684  1.000000      0.819221        0.774972
# Whole weight    0.925261  0.925452  0.819221      1.000000        0.969405
# Shucked weight  0.897914  0.893162  0.774972      0.969405        1.000000
# Viscera weight  0.903018  0.899724  0.798319      0.966375        0.931961
# Shell weight    0.897706  0.905330  0.817338      0.955355        0.882617
# Rings           0.556720  0.574660  0.557467      0.540390        0.420884
#
#                 Viscera weight  Shell weight     Rings
# Length                0.903018      0.897706  0.556720
# Diameter              0.899724      0.905330  0.574660
# Height                0.798319      0.817338  0.557467
# Whole weight          0.966375      0.955355  0.540390
# Shucked weight        0.931961      0.882617  0.420884
# Viscera weight        1.000000      0.907656  0.503819
# Shell weight          0.907656      1.000000  0.627574
# Rings                 0.503819      0.627574  1.000000

# %%
#Lets describe the abalone dataset
df_abalone.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# 25%          0.093500      0.130000     8.000000
# 50%          0.171000      0.234000     9.000000
# 75%          0.253000      0.329000    11.000000
# max          0.760000      1.005000    29.000000

# %%
#Lets draw a bar graph for Rings and Sex
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x="Sex",y="Rings",data=df_abalone)
plt.show()

# %%
df_abalone_final=pd.get_dummies(df_abalone,drop_first=True)
df_abalone_final
# Out:
#       Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0      0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1      0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2      0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3      0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4      0.330     0.255   0.080        0.2050          0.0895          0.0395
# 5      0.425     0.300   0.095        0.3515          0.1410          0.0775
# 6      0.530     0.415   0.150        0.7775          0.2370          0.1415
# 7      0.545     0.425   0.125        0.7680          0.2940          0.1495
# 8      0.475     0.370   0.125        0.5095          0.2165          0.1125
# 9      0.550     0.440   0.150        0.8945          0.3145          0.1510
# 10     0.525     0.380   0.140        0.6065          0.1940          0.1475
# 11     0.430     0.350   0.110        0.4060          0.1675          0.0810
# 12     0.490     0.380   0.135        0.5415          0.2175          0.0950
# 13     0.535     0.405   0.145        0.6845          0.2725          0.1710
# 14     0.470     0.355   0.100        0.4755          0.1675          0.0805
# 15     0.500     0.400   0.130        0.6645          0.2580          0.1330
# 16     0.355     0.280   0.085        0.2905          0.0950          0.0395
# 17     0.440     0.340   0.100        0.4510          0.1880          0.0870
# 18     0.365     0.295   0.080        0.2555          0.0970          0.0430
# 19     0.450     0.320   0.100        0.3810          0.1705          0.0750
# 20     0.355     0.280   0.095        0.2455          0.0955          0.0620
# 21     0.380     0.275   0.100        0.2255          0.0800          0.0490
# 22     0.565     0.440   0.155        0.9395          0.4275          0.2140
# 23     0.550     0.415   0.135        0.7635          0.3180          0.2100
# 24     0.615     0.480   0.165        1.1615          0.5130          0.3010
# 25     0.560     0.440   0.140        0.9285          0.3825          0.1880
# 26     0.580     0.450   0.185        0.9955          0.3945          0.2720
# 27     0.590     0.445   0.140        0.9310          0.3560          0.2340
# 28     0.605     0.475   0.180        0.9365          0.3940          0.2190
# 29     0.575     0.425   0.140        0.8635          0.3930          0.2270
# ...      ...       ...     ...           ...             ...             ...
# 4147   0.695     0.550   0.195        1.6645          0.7270          0.3600
# 4148   0.770     0.605   0.175        2.0505          0.8005          0.5260
# 4149   0.280     0.215   0.070        0.1240          0.0630          0.0215
# 4150   0.330     0.230   0.080        0.1400          0.0565          0.0365
# 4151   0.350     0.250   0.075        0.1695          0.0835          0.0355
# 4152   0.370     0.280   0.090        0.2180          0.0995          0.0545
# 4153   0.430     0.315   0.115        0.3840          0.1885          0.0715
# 4154   0.435     0.330   0.095        0.3930          0.2190          0.0750
# 4169        0.1815     10      0      1
# 4170        0.2405     10      0      1
# 4171        0.2290      8      0      1
# 4172        0.2490     11      0      0
# 4173        0.2605     10      0      1
# 4174        0.3080      9      0      1
# 4175        0.2960     10      0      0
# 4176        0.4950     12      0      1
#
# [4177 rows x 10 columns]

# %%
#Lets check the skewness
df_abalone_final.skew()
#From below output it is clear that skewness exist
# Out:
# Length           -0.639873
# Diameter         -0.609198
# Height            3.128817
# Whole weight      0.530959
# Shucked weight    0.719098
# Viscera weight    0.591852
# Shell weight      0.620927
# Rings             1.114102
# Sex_I             0.765708
# Sex_M             0.557390
# dtype: float64

# %%
#before treating skewnees lets divide the dataset into input and output
df_x=df_abalone_final.drop(columns=["Rings"])
y=df_abalone_final[["Rings"]]

# %%
#Now lets remove the skewness
for index in df_x.skew().index:
    if df_x.skew().loc[index]>0.5:
        df_x[index]=np.log1p(df_x[index])
    if df_x.skew().loc[index]<-0.5:
        df_x[index]=np.square(df_x[index])

# %%
#lets again check the skewness
df_x.skew()
# Out:
# Length           -0.068660
# Diameter         -0.026554
# Height            1.099602
# Whole weight     -0.038066
# Shucked weight    0.306439
# Viscera weight    0.375637
# Shell weight      0.315321
# Sex_I             0.765708
# Sex_M             0.557390
# dtype: float64

# %%
#Lets use decision tree regressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
def maxr2_score(regr,df_x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.20)
        regr.fit(x_train,y_train)
        y_pred = regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
#Lets use decision tree
from sklearn.tree import DecisionTreeRegressor
import numpy as np
dtr=DecisionTreeRegressor()
r_state=maxr2_score(dtr,df_x,np.log1p(y))
#We can see this model is not performing well
# Out:
# r2 score corresponding to  42  is  0.3418144587149563
# r2 score corresponding to  43  is  0.2924845031335539
# r2 score corresponding to  44  is  0.33398297178860137
# r2 score corresponding to  45  is  0.2084670569451047
# r2 score corresponding to  46  is  0.28048377719509054
# r2 score corresponding to  47  is  0.1572242116551491
# r2 score corresponding to  48  is  0.32769414205791836
# r2 score corresponding to  49  is  0.27787438354472904
# r2 score corresponding to  50  is  0.27196251076663325
# r2 score corresponding to  51  is  0.37021721286887466
# r2 score corresponding to  52  is  0.33712236582387334
# r2 score corresponding to  53  is  0.349102636772061
# r2 score corresponding to  54  is  0.27797432280038525
# r2 score corresponding to  55  is  0.21093154907253364
# r2 score corresponding to  56  is  0.26698456521660996
# r2 score corresponding to  57  is  0.2741474388665004
# r2 score corresponding to  58  is  0.2834588281730661
# r2 score corresponding to  59  is  0.25099223564453177
# r2 score corresponding to  60  is  0.2512200119558763
# r2 score corresponding to  61  is  0.29605863840306446
# r2 score corresponding to  62  is  0.26315156260022887
# r2 score corresponding to  63  is  0.3589951121136673
# r2 score corresponding to  64  is  0.28612020163107
# r2 score corresponding to  65  is  0.2732489158496244
# r2 score corresponding to  66  is  0.30119407467142123
# r2 score corresponding to  67  is  0.31762014314964393
# r2 score corresponding to  68  is  0.2660244221878729
# r2 score corresponding to  69  is  0.2431869740510879
# r2 score corresponding to  70  is  0.2776943709701075
# r2 score corresponding to  71  is  0.26150649351884003
# r2 score corresponding to  72  is  0.3079517978180547
# r2 score corresponding to  73  is  0.21733769678349635
# r2 score corresponding to  74  is  0.288273553455208
# r2 score corresponding to  75  is  0.27912837235106347
# r2 score corresponding to  76  is  0.2753111540185258
# r2 score corresponding to  77  is  0.3035137778399729
# r2 score corresponding to  78  is  0.3256317287938839
# r2 score corresponding to  79  is  0.2980005719406025
# r2 score corresponding to  80  is  0.28747870408268783
# r2 score corresponding to  81  is  0.33492701533656033
# r2 score corresponding to  82  is  0.27830220871250955
# r2 score corresponding to  83  is  0.2781259913640687
# r2 score corresponding to  84  is  0.26000573990581977
# r2 score corresponding to  85  is  0.4003772401799798
# r2 score corresponding to  86  is  0.2741490581943845
# r2 score corresponding to  87  is  0.262463414177204
# r2 score corresponding to  88  is  0.2973855019679428
# r2 score corresponding to  89  is  0.308981691424296
# r2 score corresponding to  90  is  0.29586246425687146
# r2 score corresponding to  91  is  0.27991267521895735
# r2 score corresponding to  92  is  0.2796073350057722
# r2 score corresponding to  93  is  0.2970498256594869
# r2 score corresponding to  94  is  0.2748954144746789
# r2 score corresponding to  95  is  0.26885569512040175
# r2 score corresponding to  96  is  0.1984334216754189
# r2 score corresponding to  97  is  0.2888113477749631
# r2 score corresponding to  98  is  0.28313321428199856
# r2 score corresponding to  99  is  0.3218236584387908
# max r2 score corresponding to  85  is  0.4003772401799798

# %%
#lets use random forest regressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
import warnings
warnings.filterwarnings("ignore")
rfr=RandomForestRegressor()
parameters = {"n_estimators":[10,100,500]}
clf = GridSearchCV(rfr, parameters, cv=5)
clf.fit(df_x, np.log1p(y))
clf.best_params_
# Out:
# {'n_estimators': 500}

# %%
#Lets use maxr2_score function
rfr=RandomForestRegressor(n_estimators=500)
r_state=maxr2_score(rfr,df_x,np.log1p(y))
#Below scores are better than what we saw with decision tree but random fores is some what slow
# Out:
# r2 score corresponding to  42  is  0.6407227910820386
# r2 score corresponding to  43  is  0.6491359218522681
# r2 score corresponding to  44  is  0.6438170022710277
# r2 score corresponding to  45  is  0.6004463049533202
# r2 score corresponding to  46  is  0.6408285314131235
# r2 score corresponding to  47  is  0.5883993965111497
# r2 score corresponding to  48  is  0.6464139690851289
# r2 score corresponding to  49  is  0.6167265694305066
# r2 score corresponding to  50  is  0.6299538420848143
# r2 score corresponding to  51  is  0.6676817887506736
# r2 score corresponding to  52  is  0.6566688286137323
# r2 score corresponding to  53  is  0.6540702012979944
# r2 score corresponding to  54  is  0.6007252404168939
# r2 score corresponding to  55  is  0.6200781016908918
# r2 score corresponding to  56  is  0.6300670437986498
# r2 score corresponding to  57  is  0.6390055474155101
# r2 score corresponding to  58  is  0.6475703778671588
# r2 score corresponding to  59  is  0.6356802230996592
# r2 score corresponding to  60  is  0.6185299555097361
# r2 score corresponding to  61  is  0.6315038550867502
# r2 score corresponding to  62  is  0.6325824129877492
# r2 score corresponding to  63  is  0.6540859449175854
# r2 score corresponding to  64  is  0.6285316388506899
# r2 score corresponding to  65  is  0.6286405315761652
# r2 score corresponding to  66  is  0.6430309938405212
# r2 score corresponding to  67  is  0.6402122074355341
# r2 score corresponding to  68  is  0.6044439594305452
# r2 score corresponding to  69  is  0.6388842445816201
# r2 score corresponding to  70  is  0.6326655916708495
# r2 score corresponding to  71  is  0.619969460998045
# r2 score corresponding to  72  is  0.6283636322654642
# r2 score corresponding to  73  is  0.6081215985942625
# r2 score corresponding to  74  is  0.6099345560465945
# r2 score corresponding to  75  is  0.6201647352674424
# r2 score corresponding to  76  is  0.6100960959345909
# r2 score corresponding to  77  is  0.6495385740649433
# r2 score corresponding to  78  is  0.6279854563154939
# r2 score corresponding to  79  is  0.6296067300757091
# r2 score corresponding to  80  is  0.6363286507993882
# r2 score corresponding to  81  is  0.6532574135695496
# r2 score corresponding to  82  is  0.6600450159951777
# r2 score corresponding to  83  is  0.602144517811322
# r2 score corresponding to  84  is  0.5977575290366246
# r2 score corresponding to  85  is  0.6461039240346811
# r2 score corresponding to  86  is  0.6084567536127102
# r2 score corresponding to  87  is  0.6080990671783233
# r2 score corresponding to  88  is  0.6648797582338866
# r2 score corresponding to  89  is  0.6627018992644396
# r2 score corresponding to  90  is  0.6100218232693848
# r2 score corresponding to  91  is  0.6326289673007839
# r2 score corresponding to  92  is  0.5980784024884798
# r2 score corresponding to  93  is  0.6498553317407074
# r2 score corresponding to  94  is  0.6433834209359228
# r2 score corresponding to  95  is  0.6512332578198996
# r2 score corresponding to  96  is  0.6235608187648165
# r2 score corresponding to  97  is  0.6399524448248248
# r2 score corresponding to  98  is  0.6106485432760073
# r2 score corresponding to  99  is  0.6374035201605912
# max r2 score corresponding to  51  is  0.6676817887506736

# %%
#Lets check the mean r2_score with random forest
from sklearn.model_selection import cross_val_score
cross_val_score(rfr,df_x,np.log1p(y),cv=10,scoring="r2").mean()
# Out:
# 0.5479373942228861

# %%
#Lets use KNN regressor but we will find the otimal value of n_neigbors using grid search
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
parameters = {"n_neighbors":range(2,30)}
clf = GridSearchCV(knr, parameters, cv=10)
clf.fit(df_x, np.log1p(y))
clf.best_params_
# Out:
# {'n_neighbors': 19}

# %%
#Lets use n_neighbors as found above and use maxr2_score function
knr=KNeighborsRegressor(n_neighbors=19)
r_state=maxr2_score(knr,df_x,np.log1p(y))
#KNN is giving same r2 score as rando forest
# Out:
# r2 score corresponding to  42  is  0.6459073464675045
# r2 score corresponding to  43  is  0.6408628287342826
# r2 score corresponding to  44  is  0.6374681957772583
# r2 score corresponding to  45  is  0.6108143862360764
# r2 score corresponding to  46  is  0.6272689467514001
# r2 score corresponding to  47  is  0.5829932304584157
# r2 score corresponding to  48  is  0.6466195660884659
# r2 score corresponding to  49  is  0.6186798717841864
# r2 score corresponding to  50  is  0.6040022545362569
# r2 score corresponding to  51  is  0.6423586937796422
# r2 score corresponding to  52  is  0.6317494983704686
# r2 score corresponding to  53  is  0.6392013491695201
# r2 score corresponding to  54  is  0.5873946159695398
# r2 score corresponding to  55  is  0.6158987006244095
# r2 score corresponding to  56  is  0.6334177728292447
# r2 score corresponding to  57  is  0.6268911363110413
# r2 score corresponding to  58  is  0.6501789012931287
# r2 score corresponding to  59  is  0.6341489040742534
# r2 score corresponding to  60  is  0.6269221514082195
# r2 score corresponding to  61  is  0.6119401308202924
# r2 score corresponding to  62  is  0.6369541887163055
# r2 score corresponding to  63  is  0.6362345078824114
# r2 score corresponding to  64  is  0.6097853459599163
# r2 score corresponding to  65  is  0.6075801048163275
# r2 score corresponding to  66  is  0.6155489112105847
# r2 score corresponding to  67  is  0.628793556249724
# r2 score corresponding to  68  is  0.5926002265442532
# r2 score corresponding to  69  is  0.6189094793116686
# r2 score corresponding to  70  is  0.6068411332218975
# r2 score corresponding to  71  is  0.6066610882241489
# r2 score corresponding to  72  is  0.6054633472378549
# r2 score corresponding to  73  is  0.6054913274155647
# r2 score corresponding to  74  is  0.5978085802015793
# r2 score corresponding to  75  is  0.6001157868100118
# r2 score corresponding to  76  is  0.6429370531433576
# r2 score corresponding to  77  is  0.6261845305948597
# r2 score corresponding to  78  is  0.6181712289230206
# r2 score corresponding to  79  is  0.6181252089438264
# r2 score corresponding to  80  is  0.6176956238704756
# r2 score corresponding to  81  is  0.6467457685748554
# r2 score corresponding to  82  is  0.6545209244948037
# r2 score corresponding to  83  is  0.6088725384814794
# r2 score corresponding to  84  is  0.5957201608935966
# r2 score corresponding to  85  is  0.623650129831282
# r2 score corresponding to  86  is  0.5949528814147079
# r2 score corresponding to  87  is  0.610531352987667
# r2 score corresponding to  88  is  0.6612031762705324
# r2 score corresponding to  89  is  0.6538843995515482
# r2 score corresponding to  90  is  0.5852160026307955
# r2 score corresponding to  91  is  0.621717773298456
# r2 score corresponding to  92  is  0.59005735454314
# r2 score corresponding to  93  is  0.6406443625925122
# r2 score corresponding to  94  is  0.6350541949549311
# r2 score corresponding to  95  is  0.6344068324832058
# r2 score corresponding to  96  is  0.5987337427369037
# r2 score corresponding to  97  is  0.620362784255363
# r2 score corresponding to  98  is  0.5962464213409453
# r2 score corresponding to  99  is  0.630728022025522
# max r2 score corresponding to  88  is  0.6612031762705324

# %%
#Lets find meean r2 score using cross_val score function
cross_val_score(knr,df_x,np.log1p(y),cv=10,scoring="r2").mean()
#Here mean r2 score is better than random forest regressor
# Out:
# 0.5596356602460713

# %%
#Lets use KNN regressor and save it as our final model
x_train, x_test, y_train, y_test = train_test_split(df_x, y,random_state = r_state,test_size=0.25)
y_train=np.log1p(y_train)

# %%
knr=KNeighborsRegressor(n_neighbors=19)
knr.fit(x_train,y_train)
y_pred=knr.predict(x_test)

# %%
#Lets find the rmse and r2_score using sklearn.metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,np.expm1(y_pred))))
print("r2_score is: ",r2_score(y_test,np.expm1(y_pred)) )
# Out:
# RMSE is:  2.1558883086049097
# r2_score is:  0.5526119048855596

# %%
from sklearn.externals import joblib 
  
# Save the model as a pickle in a file 
joblib.dump(knr, 'abalone_knn.pkl')
# Out:
# ['abalone_knn.pkl']
